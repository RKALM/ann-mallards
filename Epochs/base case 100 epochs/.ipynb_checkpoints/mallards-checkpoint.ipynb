# %%
#importing all the necessary libraries.
import pandas as pd
import numpy as np
from sklearn.metrics import confusion_matrix
from sklearn import tree
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense
from sklearn.metrics import mean_absolute_error, mean_squared_error
import matplotlib.pyplot as plt

# %%
#importing the initial data from the file "Mallards_initial data.xlsx"
mallards=pd.read_excel("Mallards_initial data.xlsx")
#The line bellow is used for debugging.
mallards = mallards.loc[:, ~mallards.columns.str.contains('^Unnamed')]
print(mallards.tail(5))
# Out:
#        population  farmed       date       hour  slatitude  slongitude
# 19910         111       0 2012-10-03   18:46:46  56.440178   13.992034
# 19911         111       0 2012-10-03   19:46:42  56.439957   13.992407
# 19912         111       0 2012-10-03   20:47:04  56.440022   13.992071
# 19913         111       0 2012-10-03   21:49:33  56.440029   13.992332
# 19914         111       0 2012-10-03   22:48:59  56.440067   13.993050

# %%
# instead of any other type of grouping we choose to group the mallards by ordering them by population.
ordered = mallards.sort_values(by=["population"]).reset_index(drop=True)

# %%
ordered.tail(10)
# Out:
#        population  farmed       date       hour  slatitude  slongitude
# 19905         153       1 2012-10-19   04:39:28  56.500893   13.970902
# 19906         153       1 2012-10-19   05:39:21  56.500786   13.970841
# 19907         153       1 2012-10-19   06:38:23  56.500889   13.971055
# 19908         153       1 2012-10-19   07:38:58  56.487541   13.965097
# 19909         153       1 2012-10-19   08:39:03  56.487274   13.965044
# 19910         153       1 2012-10-19   09:39:15  56.487392   13.965101
# 19911         153       1 2012-10-19   10:38:33  56.487503   13.965265
# 19912         153       1 2012-10-19   11:38:27  56.487041   13.965001
# 19913         153       1 2012-10-18   07:41:34  56.487537   13.965165
# 19914         153       1 2012-10-08   07:59:45  56.432728   13.989956

# %%
#Saving the ordered by population data into the Excel file "mallards_ordered.xlsx"
ordered.to_excel("mallards_ordered.xlsx", index=False)

# %%
#Creating the dataframe that is going to be used as y. Each column will be used as y in a different model.
labelled = pd.DataFrame(columns=["dlatitude", "dlongitude"])

#Generating the labels by making the next coordinates as the destination coordinates for the previous row.
for i, row in ordered.iterrows():
    if i == ordered.index[-1]:
        break
    if row["population"] != ordered.iloc[i+1]["population"]:
        label_row = pd.DataFrame({"dlatitude": row["slatitude"], "dlongitude": row["slongitude"]}, index=[i])
    else:
        label_row = pd.DataFrame({"dlatitude": ordered.iloc[i+1]["slatitude"], "dlongitude": ordered.iloc[i+1]["slongitude"]}, index=[i])
    labelled = pd.concat([labelled, label_row])

# %%
labelled.head(10)
# Out:
#    dlatitude  dlongitude
# 0  56.439716   13.991791
# 1  56.440170   13.992670
# 2  56.440136   13.992191
# 3  56.441143   13.988527
# 4  56.439919   13.991972
# 5  56.439869   13.992161
# 6  56.439716   13.992242
# 7  56.439934   13.991963
# 8  56.439888   13.992043
# 9  56.440109   13.991787

# %%
# drop last two rows from ordered dataframe. It is used for data management.
ordered = ordered.iloc[:-2].reset_index(drop=True)

# drop last row from labelled dataframe. It is used for data management.
labelled = labelled.iloc[:-1].reset_index(drop=True)

# %%
print(ordered.iloc[:-1].shape)
# Out:
# (19912, 6)

# %%
print(labelled["dlatitude"].iloc[:-1].shape)
# Out:
# (19912,)

# %%
# Making different splits for different models, one for longitude and one latitude.
X_train, X_test, y_lat_train, y_lat_test = train_test_split(
    ordered.iloc[:-1], labelled["dlatitude"].iloc[:-1], test_size=0.2, random_state=42
)
X_train, X_test, y_long_train, y_long_test = train_test_split(
    ordered.iloc[:-1], labelled["dlongitude"].iloc[:-1], test_size=0.2, random_state=42
)

# %%
X_train.shape
# Out:
# (15929, 6)

# %%
# We use standard scaler to do our scalling, instead of manual scaling.
scaler = StandardScaler()

# %%
# Making sure that date and hour have the necessary format.
X_train_no_date = X_train.drop(['date', 'hour'], axis=1)
X_train_scaled = scaler.fit_transform(X_train_no_date)
X_train_scaled_df = pd.DataFrame(X_train_scaled, columns=X_train_no_date.columns, index=X_train_no_date.index)
X_train_scaled_df[['date', 'hour']] = X_train[['date', 'hour']]

# %%
# Making sure that date and hour have the necessary format.
X_test_no_date = X_test.drop(['date', 'hour'], axis=1)
X_test_scaled = scaler.transform(X_test_no_date)
X_test_scaled_df = pd.DataFrame(X_test_scaled, columns=X_test_no_date.columns, index=X_test_no_date.index)
X_test_scaled_df[['date', 'hour']] = X_test[['date', 'hour']]

# %%
# extract day of the week and hour of the day from datetime columns
X_train_scaled_df['weekday'] = X_train_scaled_df['date'].dt.weekday
X_train_scaled_df['hour'] = pd.to_datetime(X_train_scaled_df['hour'].str.strip(), format='%H:%M:%S')
X_train_scaled_df['hour'] = X_train_scaled_df['hour'].dt.hour

X_test_scaled_df['weekday'] = X_test_scaled_df['date'].dt.weekday
X_test_scaled_df['hour'] = pd.to_datetime(X_test_scaled_df['hour'].str.strip(), format='%H:%M:%S')
X_test_scaled_df['hour'] = X_test_scaled_df['hour'].dt.hour

# drop the original datetime columns
X_train_scaled_df = X_train_scaled_df.drop(['date'], axis=1)
X_test_scaled_df = X_test_scaled_df.drop(['date'], axis=1)

# %%
X_train_scaled_df.tail(5)
# Out:
#        population    farmed  slatitude  slongitude  hour  weekday
# 11284    0.030042 -0.524242   0.125260    0.133639    21        5
# 11964    0.138355 -0.524242   0.127363    0.126657    19        0
# 5390    -0.879784 -0.524242   0.125449    0.134608    15        4
# 860     -1.356359 -0.524242   0.124414    0.135708    18        2
# 15795    0.939869 -0.524242   0.125983    0.133088     3        0

# %%
X_test_scaled_df.tail(5)
# Out:
#        population    farmed  slatitude  slongitude  hour  weekday
# 16564    1.113169  1.907515   0.123946    0.131636    21        4
# 19327    1.849695  1.907515  -4.781471   -1.732344    10        0
# 15022    0.874881 -0.524242   0.126517    0.128668     0        3
# 2457    -1.139734 -0.524242   0.124135    0.135700     5        1
# 9210    -0.229908 -0.524242   0.121909    0.135181    17        5

# %%
#Important part of the code. it is the place where we set our configuration.
n_units = 32
activation = 'relu'
loss_function = 'mean_squared_error'

# %%
# A separate model to detect latitude.
modelLat = Sequential()
modelLat.add(Dense(n_units, activation=activation, input_shape=(X_train_scaled_df.shape[1],)))
modelLat.add(Dense(1))
modelLat.compile(optimizer='adam', loss=loss_function)

# %%
# A separate model to detect longitude.
modelLong = Sequential()
modelLong.add(Dense(n_units, activation=activation, input_shape=(X_train_scaled_df.shape[1],)))
modelLong.add(Dense(1))
modelLong.compile(optimizer='adam', loss=loss_function)

# %%
print(X_train_scaled_df.values.shape)
# Out:
# (15929, 6)

# %%
print(y_lat_train.values.shape)
# Out:
# (15929,)

# %%
print(modelLat.input_shape)
# Out:
# (None, 6)

# %%
X_train_scaled_df.shape
# Out:
# (15929, 6)

# %%
X_test_scaled_df.shape
# Out:
# (3983, 6)

# %%
# Fitting the data in the model for latitude.
historyLat=modelLat.fit(X_train_scaled_df.values, y_lat_train, validation_data=(X_test_scaled_df.values, y_lat_test), epochs=100)
# Out:
# Epoch 1/100
# 498/498 [==============================] - 2s 4ms/step - loss: 1090.5707 - val_loss: 465.5202s - loss: 1746.
# Epoch 2/100
# 498/498 [==============================] - 2s 4ms/step - loss: 369.6013 - val_loss: 286.3021
# Epoch 3/100
# 498/498 [==============================] - 2s 3ms/step - loss: 236.6662 - val_loss: 179.7578
# Epoch 4/100
# 498/498 [==============================] - 1s 3ms/step - loss: 130.7477 - val_loss: 79.3192
# Epoch 5/100
# 498/498 [==============================] - 2s 4ms/step - loss: 44.8950 - val_loss: 19.3413
# Epoch 6/100
# 498/498 [==============================] - 1s 3ms/step - loss: 10.0475 - val_loss: 4.6603
# Epoch 7/100
# 498/498 [==============================] - 2s 3ms/step - loss: 2.7864 - val_loss: 1.5958
# Epoch 8/100
# 498/498 [==============================] - 2s 4ms/step - loss: 1.0655 - val_loss: 0.7762
# Epoch 9/100
# 498/498 [==============================] - 2s 4ms/step - loss: 0.5901 - val_loss: 0.5557
# Epoch 10/100
# 498/498 [==============================] - 1s 3ms/step - loss: 0.4195 - val_loss: 0.4217
# Epoch 11/100
# 498/498 [==============================] - 2s 4ms/step - loss: 0.3073 - val_loss: 0.3380
# Epoch 12/100
# 498/498 [==============================] - 2s 5ms/step - loss: 0.2216 - val_loss: 0.2777
# Epoch 13/100
# 498/498 [==============================] - 2s 3ms/step - loss: 0.1594 - val_loss: 0.2306
# Epoch 14/100
# 498/498 [==============================] - 2s 3ms/step - loss: 0.1256 - val_loss: 0.2127
# Epoch 15/100
# 498/498 [==============================] - 1s 3ms/step - loss: 0.1071 - val_loss: 0.2001
# Epoch 16/100
# 498/498 [==============================] - 1s 3ms/step - loss: 0.0946 - val_loss: 0.1778
# Epoch 17/100
# 498/498 [==============================] - 1s 3ms/step - loss: 0.0809 - val_loss: 0.1726
# Epoch 18/100
# 498/498 [==============================] - 1s 3ms/step - loss: 0.0701 - val_loss: 0.1605
# Epoch 19/100
# 498/498 [==============================] - 1s 3ms/step - loss: 0.0586 - val_loss: 0.1498
# Epoch 20/100
# 498/498 [==============================] - 1s 3ms/step - loss: 0.0514 - val_loss: 0.1504 ETA: 0s - los
# Epoch 21/100
# 498/498 [==============================] - 1s 3ms/step - loss: 0.0432 - val_loss: 0.1366
# Epoch 22/100
# 498/498 [==============================] - 1s 3ms/step - loss: 0.0362 - val_loss: 0.1364
# Epoch 23/100
# 498/498 [==============================] - 1s 3ms/step - loss: 0.0307 - val_loss: 0.1521
# Epoch 24/100
# 498/498 [==============================] - 1s 3ms/step - loss: 0.0246 - val_loss: 0.1302
# Epoch 25/100
# 498/498 [==============================] - 1s 2ms/step - loss: 0.0185 - val_loss: 0.1291
# Epoch 26/100
# 498/498 [==============================] - 1s 2ms/step - loss: 0.0164 - val_loss: 0.1239
# Epoch 27/100
# 498/498 [==============================] - 1s 2ms/step - loss: 0.0137 - val_loss: 0.1211
# Epoch 28/100
# 498/498 [==============================] - 1s 2ms/step - loss: 0.0101 - val_loss: 0.1182
# Epoch 29/100
# 498/498 [==============================] - 1s 3ms/step - loss: 0.0091 - val_loss: 0.1189
# Epoch 30/100
# 498/498 [==============================] - 1s 2ms/step - loss: 0.0085 - val_loss: 0.1169
# Epoch 31/100
# 498/498 [==============================] - 1s 1ms/step - loss: 0.0065 - val_loss: 0.1151
# Epoch 32/100
# 498/498 [==============================] - 1s 1ms/step - loss: 0.0074 - val_loss: 0.1139
# Epoch 33/100
# 498/498 [==============================] - 1s 2ms/step - loss: 0.0052 - val_loss: 0.1099
# Epoch 34/100
# 498/498 [==============================] - 1s 2ms/step - loss: 0.0059 - val_loss: 0.1069
# Epoch 35/100
# 498/498 [==============================] - 1s 1ms/step - loss: 0.0048 - val_loss: 0.1017
# Epoch 36/100
# 498/498 [==============================] - 1s 2ms/step - loss: 0.0055 - val_loss: 0.0989
# Epoch 37/100
# 498/498 [==============================] - 1s 1ms/step - loss: 0.0045 - val_loss: 0.0962
# Epoch 38/100
# 498/498 [==============================] - 1s 2ms/step - loss: 0.0048 - val_loss: 0.0926
# Epoch 39/100
# 498/498 [==============================] - 1s 2ms/step - loss: 0.0037 - val_loss: 0.0903
# Epoch 40/100
# 498/498 [==============================] - 1s 2ms/step - loss: 0.0040 - val_loss: 0.0887
# Epoch 41/100
# 498/498 [==============================] - 1s 2ms/step - loss: 0.0053 - val_loss: 0.0864
# Epoch 42/100
# 498/498 [==============================] - 1s 2ms/step - loss: 0.0040 - val_loss: 0.0880
# Epoch 43/100
# 498/498 [==============================] - 1s 2ms/step - loss: 0.0036 - val_loss: 0.0865
# Epoch 44/100
# 498/498 [==============================] - 1s 2ms/step - loss: 0.0046 - val_loss: 0.0902
# Epoch 45/100
# 498/498 [==============================] - 1s 2ms/step - loss: 0.0046 - val_loss: 0.0796
# Epoch 46/100
# 498/498 [==============================] - 1s 2ms/step - loss: 0.0038 - val_loss: 0.0769
# Epoch 47/100
# 498/498 [==============================] - 1s 2ms/step - loss: 0.0041 - val_loss: 0.0763
# Epoch 48/100
# 498/498 [==============================] - 1s 2ms/step - loss: 0.0037 - val_loss: 0.0798
# Epoch 49/100
# 498/498 [==============================] - 1s 2ms/step - loss: 0.0037 - val_loss: 0.0732
# Epoch 50/100
# 498/498 [==============================] - 1s 2ms/step - loss: 0.0038 - val_loss: 0.0755 ETA: 0s - loss:
# Epoch 51/100
# 498/498 [==============================] - 1s 2ms/step - loss: 0.0033 - val_loss: 0.0711
# Epoch 52/100
# 498/498 [==============================] - 1s 2ms/step - loss: 0.0032 - val_loss: 0.0719
# Epoch 53/100
# 498/498 [==============================] - 1s 1ms/step - loss: 0.0042 - val_loss: 0.0693
# Epoch 54/100
# 498/498 [==============================] - 1s 1ms/step - loss: 0.0032 - val_loss: 0.0688
# Epoch 55/100
# 498/498 [==============================] - 1s 2ms/step - loss: 0.0040 - val_loss: 0.0698
# Epoch 56/100
# 498/498 [==============================] - 1s 3ms/step - loss: 0.0036 - val_loss: 0.0638
# Epoch 57/100
# 498/498 [==============================] - 1s 3ms/step - loss: 0.0037 - val_loss: 0.0659
# Epoch 58/100
# 498/498 [==============================] - 1s 2ms/step - loss: 0.0046 - val_loss: 0.0623
# Epoch 59/100
# 498/498 [==============================] - 1s 2ms/step - loss: 0.0043 - val_loss: 0.0617
# Epoch 60/100
# 498/498 [==============================] - 1s 2ms/step - loss: 0.0032 - val_loss: 0.0606 ETA: 0s - loss:
# Epoch 61/100
# 498/498 [==============================] - 1s 2ms/step - loss: 0.0032 - val_loss: 0.0601
# Epoch 62/100
# 498/498 [==============================] - 1s 2ms/step - loss: 0.0037 - val_loss: 0.0578
# Epoch 63/100
# 498/498 [==============================] - 1s 1ms/step - loss: 0.0031 - val_loss: 0.0585
# Epoch 64/100
# 498/498 [==============================] - 1s 1ms/step - loss: 0.0030 - val_loss: 0.0586
# Epoch 65/100
# 498/498 [==============================] - 1s 2ms/step - loss: 0.0041 - val_loss: 0.0556
# Epoch 66/100
# 498/498 [==============================] - 1s 2ms/step - loss: 0.0034 - val_loss: 0.0537
# Epoch 67/100
# 498/498 [==============================] - 1s 2ms/step - loss: 0.0037 - val_loss: 0.0562
# Epoch 68/100
# 498/498 [==============================] - 1s 1ms/step - loss: 0.0036 - val_loss: 0.0527
# Epoch 69/100
# 498/498 [==============================] - 1s 1ms/step - loss: 0.0027 - val_loss: 0.0523
# Epoch 70/100
# 498/498 [==============================] - 1s 2ms/step - loss: 0.0030 - val_loss: 0.0588
# Epoch 71/100
# 498/498 [==============================] - 1s 1ms/step - loss: 0.0031 - val_loss: 0.0512
# Epoch 72/100
# 498/498 [==============================] - 1s 2ms/step - loss: 0.0052 - val_loss: 0.0520
# Epoch 73/100
# 498/498 [==============================] - 1s 2ms/step - loss: 0.0036 - val_loss: 0.0542
# Epoch 74/100
# 498/498 [==============================] - 1s 2ms/step - loss: 0.0040 - val_loss: 0.0479
# Epoch 75/100
# 498/498 [==============================] - 1s 2ms/step - loss: 0.0031 - val_loss: 0.0564
# Epoch 76/100
# 498/498 [==============================] - 1s 2ms/step - loss: 0.0026 - val_loss: 0.0493
# Epoch 77/100
# 498/498 [==============================] - 1s 3ms/step - loss: 0.0030 - val_loss: 0.0499
# Epoch 78/100
# 498/498 [==============================] - 1s 2ms/step - loss: 0.0034 - val_loss: 0.0445
# Epoch 79/100
# 498/498 [==============================] - 1s 2ms/step - loss: 0.0037 - val_loss: 0.0436
# Epoch 80/100
# 498/498 [==============================] - 1s 2ms/step - loss: 0.0031 - val_loss: 0.0447
# Epoch 81/100
# 498/498 [==============================] - 1s 2ms/step - loss: 0.0036 - val_loss: 0.0437
# Epoch 82/100
# 498/498 [==============================] - 1s 2ms/step - loss: 0.0034 - val_loss: 0.0448
# Epoch 83/100
# 498/498 [==============================] - 1s 3ms/step - loss: 0.0029 - val_loss: 0.0499
# Epoch 84/100
# 498/498 [==============================] - 1s 3ms/step - loss: 0.0035 - val_loss: 0.0414
# Epoch 85/100
# 498/498 [==============================] - 1s 1ms/step - loss: 0.0028 - val_loss: 0.0431
# Epoch 86/100
# 498/498 [==============================] - 1s 2ms/step - loss: 0.0032 - val_loss: 0.0406
# Epoch 87/100
# 498/498 [==============================] - 1s 1ms/step - loss: 0.0037 - val_loss: 0.0413
# Epoch 88/100
# 498/498 [==============================] - 1s 3ms/step - loss: 0.0030 - val_loss: 0.0503
# Epoch 89/100
# 498/498 [==============================] - 1s 3ms/step - loss: 0.0030 - val_loss: 0.0393
# Epoch 90/100
# 498/498 [==============================] - 2s 3ms/step - loss: 0.0040 - val_loss: 0.0429
# Epoch 91/100
# 498/498 [==============================] - 2s 3ms/step - loss: 0.0038 - val_loss: 0.0383
# Epoch 92/100
# 498/498 [==============================] - 2s 3ms/step - loss: 0.0026 - val_loss: 0.0396
# Epoch 93/100
# 498/498 [==============================] - 1s 3ms/step - loss: 0.0029 - val_loss: 0.0402
# Epoch 94/100
# 498/498 [==============================] - 1s 3ms/step - loss: 0.0029 - val_loss: 0.0388
# Epoch 95/100
# 498/498 [==============================] - 1s 3ms/step - loss: 0.0050 - val_loss: 0.0395 ETA: 0s
# Epoch 96/100
# 498/498 [==============================] - 1s 3ms/step - loss: 0.0027 - val_loss: 0.0373
# Epoch 97/100
# 498/498 [==============================] - 1s 2ms/step - loss: 0.0030 - val_loss: 0.0375
# Epoch 98/100
# 498/498 [==============================] - 1s 2ms/step - loss: 0.0035 - val_loss: 0.0362
# Epoch 99/100
# 498/498 [==============================] - 1s 2ms/step - loss: 0.0036 - val_loss: 0.0359
# Epoch 100/100
# 498/498 [==============================] - 1s 2ms/step - loss: 0.0025 - val_loss: 0.0342

# %%
# Fitting the data in the model for latitude.
historyLong=modelLong.fit(X_train_scaled_df.values, y_long_train, validation_data=(X_test_scaled_df.values, y_long_test), epochs=100)
# Out:
# Epoch 1/100
# 498/498 [==============================] - 2s 3ms/step - loss: 45.6062 - val_loss: 11.6645
# Epoch 2/100
# 498/498 [==============================] - 1s 3ms/step - loss: 5.9238 - val_loss: 2.1608
# Epoch 3/100
# 498/498 [==============================] - 1s 2ms/step - loss: 1.0792 - val_loss: 0.5518
# Epoch 4/100
# 498/498 [==============================] - 1s 2ms/step - loss: 0.3127 - val_loss: 0.1969
# Epoch 5/100
# 498/498 [==============================] - 1s 3ms/step - loss: 0.1131 - val_loss: 0.0875
# Epoch 6/100
# 498/498 [==============================] - 1s 2ms/step - loss: 0.0536 - val_loss: 0.0553
# Epoch 7/100
# 498/498 [==============================] - 1s 2ms/step - loss: 0.0338 - val_loss: 0.0440
# Epoch 8/100
# 498/498 [==============================] - 1s 2ms/step - loss: 0.0255 - val_loss: 0.0369
# Epoch 9/100
# 498/498 [==============================] - 1s 2ms/step - loss: 0.0209 - val_loss: 0.0344
# Epoch 10/100
# 498/498 [==============================] - 1s 2ms/step - loss: 0.0178 - val_loss: 0.0339
# Epoch 11/100
# 498/498 [==============================] - 1s 2ms/step - loss: 0.0162 - val_loss: 0.0313
# Epoch 12/100
# 498/498 [==============================] - 1s 2ms/step - loss: 0.0139 - val_loss: 0.0324
# Epoch 13/100
# 498/498 [==============================] - 1s 2ms/step - loss: 0.0122 - val_loss: 0.0313
# Epoch 14/100
# 498/498 [==============================] - 1s 3ms/step - loss: 0.0111 - val_loss: 0.0296
# Epoch 15/100
# 498/498 [==============================] - 1s 3ms/step - loss: 0.0096 - val_loss: 0.0303
# Epoch 16/100
# 498/498 [==============================] - 1s 2ms/step - loss: 0.0085 - val_loss: 0.0284
# Epoch 17/100
# 498/498 [==============================] - 1s 2ms/step - loss: 0.0080 - val_loss: 0.0276
# Epoch 18/100
# 498/498 [==============================] - 1s 2ms/step - loss: 0.0075 - val_loss: 0.0272
# Epoch 19/100
# 498/498 [==============================] - 1s 3ms/step - loss: 0.0074 - val_loss: 0.0269
# Epoch 20/100
# 498/498 [==============================] - 1s 2ms/step - loss: 0.0071 - val_loss: 0.0324
# Epoch 21/100
# 498/498 [==============================] - 1s 2ms/step - loss: 0.0069 - val_loss: 0.0278
# Epoch 22/100
# 498/498 [==============================] - 1s 2ms/step - loss: 0.0068 - val_loss: 0.0274
# Epoch 23/100
# 498/498 [==============================] - ETA: 0s - loss: 0.006 - 1s 2ms/step - loss: 0.0065 - val_loss: 0.0265
# Epoch 24/100
# 498/498 [==============================] - 1s 2ms/step - loss: 0.0068 - val_loss: 0.0272
# Epoch 25/100
# 498/498 [==============================] - 1s 2ms/step - loss: 0.0066 - val_loss: 0.0270ETA: 0s - lo
# Epoch 26/100
# 498/498 [==============================] - 1s 2ms/step - loss: 0.0060 - val_loss: 0.0264
# Epoch 27/100
# 498/498 [==============================] - 1s 2ms/step - loss: 0.0058 - val_loss: 0.0262
# Epoch 28/100
# 498/498 [==============================] - 1s 2ms/step - loss: 0.0059 - val_loss: 0.0240
# Epoch 29/100
# 498/498 [==============================] - 1s 3ms/step - loss: 0.0059 - val_loss: 0.0236
# Epoch 30/100
# 498/498 [==============================] - 1s 2ms/step - loss: 0.0057 - val_loss: 0.0276
# Epoch 31/100
# 498/498 [==============================] - 1s 2ms/step - loss: 0.0058 - val_loss: 0.0239
# Epoch 32/100
# 498/498 [==============================] - 1s 2ms/step - loss: 0.0057 - val_loss: 0.0219
# Epoch 33/100
# 498/498 [==============================] - 1s 3ms/step - loss: 0.0062 - val_loss: 0.0213
# Epoch 34/100
# 498/498 [==============================] - 1s 3ms/step - loss: 0.0055 - val_loss: 0.0215
# Epoch 35/100
# 498/498 [==============================] - 1s 2ms/step - loss: 0.0056 - val_loss: 0.0205
# Epoch 36/100
# 498/498 [==============================] - 1s 2ms/step - loss: 0.0056 - val_loss: 0.0271
# Epoch 37/100
# 498/498 [==============================] - 1s 2ms/step - loss: 0.0055 - val_loss: 0.0197
# Epoch 38/100
# 498/498 [==============================] - 1s 2ms/step - loss: 0.0056 - val_loss: 0.0189
# Epoch 39/100
# 498/498 [==============================] - 1s 2ms/step - loss: 0.0057 - val_loss: 0.0193- ETA: 0s - loss: 0.
# Epoch 40/100
# 498/498 [==============================] - 1s 2ms/step - loss: 0.0055 - val_loss: 0.0188
# Epoch 41/100
# 498/498 [==============================] - 1s 2ms/step - loss: 0.0052 - val_loss: 0.0183
# Epoch 42/100
# 498/498 [==============================] - 2s 4ms/step - loss: 0.0052 - val_loss: 0.0186
# Epoch 43/100
# 498/498 [==============================] - 1s 2ms/step - loss: 0.0053 - val_loss: 0.0190
# Epoch 44/100
# 498/498 [==============================] - 1s 2ms/step - loss: 0.0055 - val_loss: 0.0188 ETA: 0s - loss: 0.00
# Epoch 45/100
# 498/498 [==============================] - 1s 2ms/step - loss: 0.0052 - val_loss: 0.0186
# Epoch 46/100
# 498/498 [==============================] - 1s 2ms/step - loss: 0.0053 - val_loss: 0.0188
# Epoch 47/100
# 498/498 [==============================] - 1s 2ms/step - loss: 0.0053 - val_loss: 0.0177
# Epoch 48/100
# 498/498 [==============================] - 1s 2ms/step - loss: 0.0054 - val_loss: 0.0175
# Epoch 49/100
# 498/498 [==============================] - 1s 2ms/step - loss: 0.0050 - val_loss: 0.0195
# Epoch 50/100
# 498/498 [==============================] - 1s 2ms/step - loss: 0.0059 - val_loss: 0.0171
# Epoch 51/100
# 498/498 [==============================] - 1s 2ms/step - loss: 0.0054 - val_loss: 0.0165
# Epoch 52/100
# 498/498 [==============================] - 1s 2ms/step - loss: 0.0053 - val_loss: 0.0178
# Epoch 53/100
# 498/498 [==============================] - 1s 2ms/step - loss: 0.0051 - val_loss: 0.0151
# Epoch 54/100
# 498/498 [==============================] - 1s 1ms/step - loss: 0.0049 - val_loss: 0.0174
# Epoch 55/100
# 498/498 [==============================] - 1s 2ms/step - loss: 0.0052 - val_loss: 0.0149
# Epoch 56/100
# 498/498 [==============================] - 1s 1ms/step - loss: 0.0053 - val_loss: 0.0143
# Epoch 57/100
# 498/498 [==============================] - 1s 2ms/step - loss: 0.0052 - val_loss: 0.0143
# Epoch 58/100
# 498/498 [==============================] - 1s 1ms/step - loss: 0.0052 - val_loss: 0.0180
# Epoch 59/100
# 498/498 [==============================] - 1s 2ms/step - loss: 0.0052 - val_loss: 0.0150
# Epoch 60/100
# 498/498 [==============================] - 1s 2ms/step - loss: 0.0053 - val_loss: 0.0146
# Epoch 61/100
# 498/498 [==============================] - 1s 2ms/step - loss: 0.0053 - val_loss: 0.0147
# Epoch 62/100
# 498/498 [==============================] - 1s 2ms/step - loss: 0.0051 - val_loss: 0.0161
# Epoch 63/100
# 498/498 [==============================] - 1s 2ms/step - loss: 0.0052 - val_loss: 0.0173
# Epoch 64/100
# 498/498 [==============================] - 1s 2ms/step - loss: 0.0051 - val_loss: 0.0126
# Epoch 65/100
# 498/498 [==============================] - 1s 2ms/step - loss: 0.0051 - val_loss: 0.0131
# Epoch 66/100
# 498/498 [==============================] - 1s 2ms/step - loss: 0.0052 - val_loss: 0.0158
# Epoch 67/100
# 498/498 [==============================] - 1s 1ms/step - loss: 0.0052 - val_loss: 0.0121
# Epoch 68/100
# 498/498 [==============================] - 1s 2ms/step - loss: 0.0055 - val_loss: 0.0118
# Epoch 69/100
# 498/498 [==============================] - 1s 2ms/step - loss: 0.0051 - val_loss: 0.0125
# Epoch 70/100
# 498/498 [==============================] - 1s 1ms/step - loss: 0.0049 - val_loss: 0.0119
# Epoch 71/100
# 498/498 [==============================] - 1s 1ms/step - loss: 0.0051 - val_loss: 0.0124
# Epoch 72/100
# 498/498 [==============================] - 1s 1ms/step - loss: 0.0048 - val_loss: 0.0136
# Epoch 73/100
# 498/498 [==============================] - 1s 1ms/step - loss: 0.0051 - val_loss: 0.0113
# Epoch 74/100
# 498/498 [==============================] - 1s 1ms/step - loss: 0.0050 - val_loss: 0.0112
# Epoch 75/100
# 498/498 [==============================] - 1s 2ms/step - loss: 0.0051 - val_loss: 0.0119
# Epoch 76/100
# 498/498 [==============================] - 1s 1ms/step - loss: 0.0049 - val_loss: 0.0112
# Epoch 77/100
# 498/498 [==============================] - 1s 2ms/step - loss: 0.0048 - val_loss: 0.0109
# Epoch 78/100
# 498/498 [==============================] - 1s 2ms/step - loss: 0.0049 - val_loss: 0.0163
# Epoch 79/100
# 498/498 [==============================] - 1s 2ms/step - loss: 0.0054 - val_loss: 0.0126
# Epoch 80/100
# 498/498 [==============================] - 1s 3ms/step - loss: 0.0053 - val_loss: 0.0108
# Epoch 81/100
# 498/498 [==============================] - 2s 4ms/step - loss: 0.0048 - val_loss: 0.0133ETA: 0s - loss:  - ETA: 0s - loss: 0.
# Epoch 82/100
# 498/498 [==============================] - 1s 3ms/step - loss: 0.0051 - val_loss: 0.0107
# Epoch 83/100
# 498/498 [==============================] - 2s 3ms/step - loss: 0.0054 - val_loss: 0.0112
# Epoch 84/100
# 498/498 [==============================] - 2s 3ms/step - loss: 0.0053 - val_loss: 0.0105
# Epoch 85/100
# 498/498 [==============================] - 1s 3ms/step - loss: 0.0050 - val_loss: 0.0121
# Epoch 86/100
# 498/498 [==============================] - 2s 4ms/step - loss: 0.0048 - val_loss: 0.0111
# Epoch 87/100
# 498/498 [==============================] - 2s 4ms/step - loss: 0.0049 - val_loss: 0.0136
# Epoch 88/100
# 498/498 [==============================] - 2s 3ms/step - loss: 0.0052 - val_loss: 0.0098
# Epoch 89/100
# 498/498 [==============================] - 2s 3ms/step - loss: 0.0049 - val_loss: 0.0122
# Epoch 90/100
# 498/498 [==============================] - 1s 3ms/step - loss: 0.0051 - val_loss: 0.0097
# Epoch 91/100
# 498/498 [==============================] - 1s 2ms/step - loss: 0.0054 - val_loss: 0.0116
# Epoch 92/100
# 498/498 [==============================] - 1s 2ms/step - loss: 0.0050 - val_loss: 0.0096
# Epoch 93/100
# 498/498 [==============================] - 1s 3ms/step - loss: 0.0051 - val_loss: 0.0097
# Epoch 94/100
# 498/498 [==============================] - 1s 3ms/step - loss: 0.0048 - val_loss: 0.0104
# Epoch 95/100
# 498/498 [==============================] - 1s 2ms/step - loss: 0.0049 - val_loss: 0.0096
# Epoch 96/100
# 498/498 [==============================] - 1s 2ms/step - loss: 0.0053 - val_loss: 0.0097
# Epoch 97/100
# 498/498 [==============================] - 1s 2ms/step - loss: 0.0050 - val_loss: 0.0121
# Epoch 98/100
# 498/498 [==============================] - 1s 2ms/step - loss: 0.0050 - val_loss: 0.0098
# Epoch 99/100
# 498/498 [==============================] - 1s 2ms/step - loss: 0.0050 - val_loss: 0.0103
# Epoch 100/100
# 498/498 [==============================] - 1s 1ms/step - loss: 0.0053 - val_loss: 0.0093

# %%
# Predict the Longitude values for the test set
y_long_pred = modelLong.predict(X_test_scaled_df)

# Compute the mean absolute error and root mean squared error
mae = mean_absolute_error(y_long_test, y_long_pred)
rmse = mean_squared_error(y_long_test, y_long_pred, squared=False)

# Print the MAE and RMSE
print('Mean Absolute Error (MAE):', mae)
print('Root Mean Squared Error (RMSE):', rmse)
# Out:
# Mean Absolute Error (MAE): 0.015463259035930774
# Root Mean Squared Error (RMSE): 0.09625881348318391

# %%
# Predict the Latitude values for the test set
y_lat_pred = modelLat.predict(X_test_scaled_df)

# Compute the mean absolute error and root mean squared error
mae = mean_absolute_error(y_lat_test, y_lat_pred)
rmse = mean_squared_error(y_lat_test, y_lat_pred, squared=False)

# Print the MAE and RMSE
print('Mean Absolute Error (MAE):', mae)
print('Root Mean Squared Error (RMSE):', rmse)
# Out:
# Mean Absolute Error (MAE): 0.020195246930374514
# Root Mean Squared Error (RMSE): 0.18485064806864834

# %%
# create scatter plot
plt.scatter(y_lat_pred, y_long_pred, c='r', label='Predicted')
plt.scatter(y_lat_test, y_long_test, c='b', label='Test')

# add labels and legend
plt.xlabel('Latitude')
plt.ylabel('Longitude')
plt.legend()

# show plot
plt.show()

# %%
X_test["population"].shape
# Out:
# (3983,)

# %%
y_lat_test_comb = pd.DataFrame(y_lat_test)
y_lat_test_comb.shape
# Out:
# (3983, 1)

# %%
y_long_test_comb = pd.DataFrame(y_long_test)
y_long_test_comb.shape
# Out:
# (3983, 1)

# %%
y_lat_pred_comb = pd.DataFrame(y_lat_pred)
y_lat_pred_comb.shape
# Out:
# (3983, 1)

# %%
y_long_pred_comb = pd.DataFrame(y_long_pred)
y_long_pred_comb.shape
# Out:
# (3983, 1)

# %%
pop_df = pd.DataFrame(X_test["population"].values.reshape(-1, 1))
pop_df.shape
# Out:
# (3983, 1)

# %%
# Create a dataframe with all the values, (predicted and actual), in order to be used for diagrams and comparisons.
combined_df = pd.concat([pop_df, y_lat_pred_comb, y_long_pred_comb, y_lat_test_comb, y_long_test_comb], axis=1)
combined_df.columns = ["population", "Pred_latitude", "Pred_longitude", "latitude", "longitude"]

# %%
combined_df = combined_df.dropna()

# %%
combined_df.head(50)
# Out:
#      population  Pred_latitude  Pred_longitude   latitude  longitude
# 0          71.0      56.439400       13.972314  56.439716  13.991791
# 3          88.0      56.439896       14.000566  56.441143  13.988527
# 6         131.0      56.426506       13.980458  56.439716  13.992242
# 17         27.0      56.441608       13.987143  56.439903  13.992476
# 19         23.0      56.435852       13.976227  56.439484  13.992446
# 31         67.0      56.434410       13.996214  56.439350  13.992638
# 34         24.0      56.427174       13.988886  56.440166  13.992716
# 35        131.0      56.422646       13.981709  56.439930  13.992993
# 41        152.0      56.424347       13.994967  56.440140  13.992735
# 42        152.0      56.428490       13.996836  56.440044  13.992678
# 46         31.0      56.407021       13.986734  56.439293  13.992464
# 47          6.0      56.444283       13.975908  56.440098  13.992357
# 49         81.0      56.412678       13.988840  56.439430  13.992407
# 50        107.0      56.440777       13.995537  56.440014  13.992168
# 54         99.0      56.417370       14.008610  56.440010  13.992728
# 57        121.0      56.426010       13.981684  56.439457  13.992411
# 59         99.0      56.430611       13.992497  56.440010  13.992560
# 72         23.0      56.440861       13.987293  56.440086  13.992273
# 88         12.0      56.441319       14.004070  56.439941  13.992248
# 99         18.0      56.426998       14.000589  56.440105  13.992232
# 101        71.0      56.411430       13.963186  56.440216  13.992801
# 102        31.0      56.428696       13.998758  56.440006  13.992887
# 103        57.0      56.437641       13.993622  56.439808  13.992372
# 115       100.0      56.425175       13.988735  56.439846  13.992750
# 119        46.0      56.432220       13.979114  56.440243  13.992171
# 121        99.0      56.421356       13.985374  56.440048  13.992293
# 123        39.0      56.435822       13.985932  56.440041  13.992390
# 127       100.0      56.430943       13.980781  56.440010  13.992611
# 130         5.0      56.444687       13.987108  56.439896  13.992273
# 134        55.0      56.425549       13.991120  56.440018  13.992618
# 137        22.0      56.443436       13.982067  56.440041  13.992442
# 139         7.0      56.458073       13.999144  56.439503  13.992475
# 146        17.0      56.424675       13.986788  56.440063  13.992658
# 169        22.0      56.453583       13.985630  56.440117  13.991635
# 180       118.0      56.428322       13.981310  56.440098  13.992248
# 181       152.0      56.426231       13.993158  56.440220  13.992155
# 182        81.0      56.421875       13.986411  56.440155  13.992286
# 196       131.0      56.441673       14.005412  56.439926  13.991809
# 200        46.0      56.425247       13.968769  56.439968  13.992654
# 205        33.0      56.434551       13.997837  56.439945  13.991898
# 210       112.0      56.430779       13.995031  56.439323  13.993193
# 217        23.0      56.429085       13.985292  56.439400  13.992448
# 218       152.0      56.423775       13.995728  56.440342  13.992517
# 221        18.0      56.488178       13.983268  56.439781  13.992595
# 222         5.0      56.437481       13.993195  56.439747  13.992553
# 230       108.0      56.437187       13.992685  56.439739  13.992417
# 241        39.0      56.443325       13.985723  56.440105  13.992458
# 247       128.0      56.425629       13.998217  56.440105  13.992502
# 251        42.0      56.427574       13.986855  56.439693  13.992349
# 254        20.0      56.429211       13.962900  56.439980  13.991875

# %%
#selecting the most frequent population of the populations that have more than 20 members.
threshold = 20
populations_above_threshold = combined_df['population'].value_counts()[combined_df['population'].value_counts() >= threshold].index
if len(populations_above_threshold) > 0:
    most_frequent_pop = combined_df.loc[combined_df['population'].isin(populations_above_threshold)]['population'].value_counts().idxmax()
    most_frequent_pop_df = combined_df.loc[combined_df['population'] == most_frequent_pop]
else:
    print("change the threshold!")

# %%
most_frequent_pop_df.head(50)
# Out:
#       population  Pred_latitude  Pred_longitude   latitude  longitude
# 41         152.0      56.424347       13.994967  56.440140  13.992735
# 42         152.0      56.428490       13.996836  56.440044  13.992678
# 181        152.0      56.426231       13.993158  56.440220  13.992155
# 218        152.0      56.423775       13.995728  56.440342  13.992517
# 257        152.0      56.048599       13.342387  56.439884  13.991575
# 449        152.0      56.394577       13.965388  56.439644  13.992051
# 466        152.0      56.419441       13.973816  56.439968  13.992618
# 836        152.0      56.401676       13.981187  56.439949  13.992587
# 1010       152.0      56.409458       14.008857  56.439953  13.993013
# 1063       152.0      56.423203       13.971048  56.439720  13.992579
# 1090       152.0      56.421532       13.994975  56.440136  13.992346
# 1148       152.0      56.427570       13.977409  56.439980  13.992707
# 1166       152.0      56.425327       13.974850  56.439777  13.992397
# 1208       152.0      55.412899       11.817486  56.440083  13.992308
# 1430       152.0      55.486427       11.765157  56.439785  13.992099
# 1453       152.0      56.425728       13.974670  56.439907  13.992694
# 1604       152.0      56.406952       13.980276  56.440128  13.992527
# 2386       152.0      55.441093       11.904726  56.440029  13.991893
# 2546       152.0      55.369896       11.986881  56.425560  14.012038
# 2554       152.0      56.426315       14.021740  56.425797  14.012887
# 2912       152.0      56.398636       13.981583  56.440105  13.992315
# 2935       152.0      56.405899       13.980022  56.440006  13.992537
# 2937       152.0      55.286396       12.061043  56.440094  13.992022
# 3024       152.0      55.294315       11.991788  56.439663  13.992376
# 3070       152.0      56.397388       13.980320  56.439842  13.992317
# 3189       152.0      56.401459       13.982584  56.479015  13.995407
# 3222       152.0      56.411091       13.977576  56.487049  13.965223
# 3256       152.0      56.426460       13.994349  56.508564  13.970716
# 3585       152.0      56.422676       13.994588  56.426220  14.012679
# 3649       152.0      56.426895       13.975169  56.439590  13.991983
# 3652       152.0      56.424889       13.993941  56.440281  13.992387
# 3656       152.0      55.653610       11.779491  56.440235  13.992384
# 3733       152.0      56.420296       13.986094  56.439682  13.992581
# 3753       152.0      55.368504       11.683697  56.440136  13.992887
# 3901       152.0      56.406471       13.980484  56.439945  13.992493
# 3934       152.0      56.371090       13.931535  56.439953  13.991904
# 3964       152.0      56.418827       13.976035  56.439972  13.992444

# %%
# Filter for rows with non-null predicted and true coordinates
filtered_df = most_frequent_pop_df.dropna(subset=['Pred_latitude', 'Pred_longitude', 'latitude', 'longitude'])

# Create scatter plot of predicted and true coordinates
plt.scatter(filtered_df['Pred_longitude'], filtered_df['Pred_latitude'], c='r', label='Predicted')
plt.scatter(filtered_df['longitude'], filtered_df['latitude'], c='b', label='True')

# Connect predicted and true coordinates with lines
for index, row in filtered_df.iterrows():
    plt.plot([row['Pred_longitude'], row['longitude']], [row['Pred_latitude'], row['latitude']], 'k-', alpha=0.3)

# Add legend and labels
plt.legend()
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.title(f"Coordinates for population {most_frequent_pop} (n={len(filtered_df)})")

# Show plot
plt.show()

# %%
most_frequent_pop_df.shape
# Out:
# (37, 5)

# %%
# Removing outliers
filtered_df = filtered_df[(filtered_df['Pred_longitude'] >= 13.7) & (filtered_df['longitude'] >= 13.7)]

# %%
# Create scatter plot of predicted and true coordinates
plt.scatter(filtered_df['Pred_longitude'], filtered_df['Pred_latitude'], c='r', label='Predicted')
plt.scatter(filtered_df['longitude'], filtered_df['latitude'], c='b', label='True')

# Connect predicted and true coordinates with lines
for index, row in filtered_df.iterrows():
    plt.plot([row['Pred_longitude'], row['longitude']], [row['Pred_latitude'], row['latitude']], 'k-', alpha=0.3)

# Add legend and labels
plt.legend()
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.title(f"Coordinates for population {most_frequent_pop} (n={len(filtered_df)})")

# Show plot
plt.show()

# %%
# Removing outliers
combined_df = combined_df[(combined_df['Pred_longitude'] >= 13.7) & (combined_df['longitude'] >= 13.7)]

# %%
# Create scatter plot of predicted and true coordinates
plt.scatter(combined_df['Pred_longitude'], combined_df['Pred_latitude'], c='r', label='Predicted')
plt.scatter(combined_df['longitude'], combined_df['latitude'], c='b', label='True')

# Connect predicted and true coordinates with lines
for index, row in combined_df.iterrows():
    plt.plot([row['Pred_longitude'], row['longitude']], [row['Pred_latitude'], row['latitude']], 'k-', alpha=0.3)

# Add legend and labels
plt.legend()
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.title(f"Coordinates for all populations")

# Show plot
plt.show()
